# %% [markdown]
# ## Import packages and Load target data

# %%
import pandas as pd
from scipy.stats import chi2_contingency

target = pd.read_csv('target.csv')

# %% [markdown]
# ## Create Turing Test data

# %%
print(bool('\n'))
# Out:
# True

# %%
# Human data
def load_maintnorm_sentences(file_path):
    dirty_sentences = []
    clean_sentences = []
    current_dirty = []
    current_clean = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if not line:  # Empty line means a new sentence
                if current_dirty and current_clean:
                    dirty_sentences.append(' '.join(current_dirty))
                    clean_sentences.append(' '.join(current_clean))
                    current_dirty = []
                    current_clean = []
            else:
                parts = line.split('\t')
                if len(parts) > 1:
                    dirty, clean = parts[0], parts[1]
                    if not clean in ['<id>', '-']:
                        current_dirty.append(dirty.lower())
                    current_clean.append(clean.lower())
    return dirty_sentences, clean_sentences

train_dirty, train_clean = load_maintnorm_sentences('../data/MaintNorm/train.norm')
test_dirty, test_clean = load_maintnorm_sentences('../data/MaintNorm/test.norm')
val_dirty, val_clean = load_maintnorm_sentences('../data/MaintNorm/val.norm')
full_dirty = train_dirty + test_dirty + val_dirty
data = list(set(full_dirty)) # remove duplicates
print(data)
# Out:
# ['blocked fuel filter warning on', 'hyd ladder not working', '1000h mech grader po', 'repair coolant leak from sight glasses', 'ros hoses u/s', 'cab light u/s', 'top right headlight blown', 'drag loop 6 iov flts', 'replace windscreen wiper blade', 'both swing lube solenoid seal valve u/s', 'fit new version rear id', 'cannon & spray rate faulty', 'investigate feed fault', 'stuck in first gear', 'servise flap locking pin sticky', 'repair leaking radiator', 're pump drive', 'weld blocks to bucket heels', 'mv3594-cam inspection', 'repair rhr hid not working', 'replace turbo oil line', '649 hr preventative maintenance', 'fit get', 'unfiltered iol presure sensor u/s', 'repair hoist transformer connection', 'sw # 8 brake req adjusting', 'weld repairs to whinch frame', 'repair fuel gauge', 'replace dogbone pins and bushes', 'replace r/h lift cylinder', 'replace worn out air tank hose', '250h mech s truck granite', 'repair start fault and repair aff', 'install antiskid stairs for pit 1&2', 'remove trans overhaul park brake po', 'right deck mcc strip/clean/inspect', 'r reverse light loose', 'replace missing pin on ladder', 'top rail cracks in bucket', 'uf2558-insp mast raise cyl pin rht low', 'hose blown fan case drain', 'fire supp went off-inv & repair', '1000h 1000hr service & insp po', 'repair cracks in tray', "replace main drive uni's", 'ndt a clevis weld & pin vi mt ut', 'repair alarm fault in cab', 'charge air conditioner', 'missing bolts from track frame', 'repl faulty condenser fans', 'system low voltage', 'tub cable re-route', 'swing no1 vertical shaft-mechanical', 'blow out gensets electrical', 'cw reseal fan pump', 'replace battery isolator on', 'lh f/drive severe oil sample result', 'brake booster leaks when trailer brakes', 'lean for remington wksp wk13', 'replace isolators', 'repair oil leak around trans', 'cable work 08/07/0011', 'rep broken fire supp bracket', 'ladder fault', 'un7986-c/out turbo primary rht frnt', '7194 7071 site insp by t&s', 'switch/control to overide pump u/', 'rear of tranny oil leak', 'repair l/h steering cylinder', 'house & boom lights u/s', 'no cab 240v cab power', 'broken bolts on swing pinion 5&6', "cw wk1566-c/out uni's eng-pump drv", 'leaking pipe on front of power divider', 'outside cab h/rail cracked', 'qr0218-inspect track roller 9 rht', 'rear ladder latch', 'test / repair air /con system', 'p/brake not releasing', 'tyre sensors for pos 8 & 0', 'replace auto', 'replace pto control solenoid', 'repl pos1 tyre', 'rear a/c compressor clutch u/s', 'argon machine service 500hr', 'replace pos 9 guard', 'qr0218- c/o no2 a/c compressor', 'horiz fairleads sheave c/out-mech', 'hydraulic fault', 'remove cable loop around tub', 'replace pos 6 tyre -mismatch', 'repl worn bucket pins', 'check oil leak on drag', 'inspect exhaust brake operation', 'repl r/h steering cyl', 'repl implement valve manifold', 'tension all collets bolts', 'repair elect fault in dash', 'grind and blend arch impact marks', '7 monthly lube panel i/o service', 'l/h/s lower suspenion rope pin retainer', 'repl r/h crowd hose', 'change out r/h steering cylinder', 'side engine mounts have movement', 'inspect and clean', 'pre-shut tub internal inspection', 'pos 1 turbo failure', 'reset drag limits', 'repl l/h x-over pipe on lift cyl', '1000h insp hyd cyl mast raise rh', 'bonnet lift cylinder u/s change out', 'replace pos 3&4 labour only', 'repair steer lock lever', 'replace reverse camera', 'pin fill out on shackle', 'replace steering joystick', 'replace bucket to be closed', 'no dash lights behind keypad', 'replace rear axle trunion', '250h mech svce drill po', '4000h mech svce eng tune', 'replace cab pressuriser fan', 'investigate cab door seals worn', 'c/o steering hose', 'xw7976- low power fault', 'tanks to be changed due to contamination', 'replace faulty door latch', 'repair r/h lift cylinder', 'replace rear wiper motor', 'replace pos 3 brake caliper + kit', '7000h mech repl turbo prim rh', 'intercoms working intermittantly', 'repla ...

# %%
# Synthetic data

# %% [markdown]
# ## Evaluate human predictions on Turing Test data

# %%
evaluator = pd.read_csv('evaluator.csv')

evaluate = pd.merge(target, evaluator, on='Sentence')

accuracy = (evaluate['Human/Synthetic_x'] == evaluate['Human/Synthetic_y']).mean()

# %%
# Observed counts
# Count of correct identifications
correct_human = ((evaluate['Human/Synthetic_x'] == 'h') & (evaluate['Human/Synthetic_y'] == 'h')).sum()
correct_synthetic = ((evaluate['Human/Synthetic_x'] == 's') & (evaluate['Human/Synthetic_y'] == 's')).sum()
# Count of incorrect identifications
incorrect_human = ((evaluate['Human/Synthetic_x'] == 'h') & (evaluate['Human/Synthetic_y'] == 's')).sum()
incorrect_synthetic = ((evaluate['Human/Synthetic_x'] == 's') & (evaluate['Human/Synthetic_y'] == 'h')).sum()

# Contingency table
observed_counts = [[correct_human, incorrect_human],
                   [incorrect_synthetic, correct_synthetic]]

# Chi-square test
chi2, p, dof, expected = chi2_contingency(observed_counts)

# Accuracy
accuracy = (correct_human + correct_synthetic) / len(evaluate)

# Print results
print(f'Chi-square: {chi2:.2f}')
print(f'p-value: {p:.2f}')
print(f'Degrees of freedom: {dof}')
print('Expected counts:')
print(expected)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Chi-square: 0.00
# p-value: 1.00
# Degrees of freedom: 1
# Expected counts:
# [[2.5 2.5]
#  [2.5 2.5]]
# Accuracy: 0.60
